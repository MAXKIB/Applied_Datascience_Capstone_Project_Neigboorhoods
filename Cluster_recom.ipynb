# %%
import numpy as np # library to handle data in a vectorized manner

import pandas as pd # library for data analsysis
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

import json # library to handle JSON files

# !conda install -c conda-forge geopy --yes # uncomment this line if you haven't completed the Foursquare API lab
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values

import requests # library to handle requests
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors
import matplotlib.pyplot as plt

import csv # implements classes to read and write tabular data in CSV form
#!conda install -c conda-forge folium=0.5.0 --yes # uncomment this line if you haven't completed the Foursquare API lab

import folium # map rendering library

# import the library to open URLs
import urllib.request

# import k-means from clustering stage
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score

# !conda install -c conda-forge folium=0.5.0 --yes # uncomment this line if you haven't completed the Foursquare API lab
import folium # map rendering library

print('Libraries imported.')
# Out:
# ...
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /home/marcus/anaconda3
#
#   added / updated specs:
#     - geopy
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     conda-4.7.9                |           py36_0         3.0 MB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         3.0 MB
#
# The following packages will be UPDATED:
#
#   conda                                        4.7.8-py36_0 --> 4.7.9-py36_0
#
#
#
# ...
# conda-4.7.9          | 3.0 MB    | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# ...
# Solving environment: done
#
# # All requested packages already installed.
#
# Libraries imported.

# %%
#LF = pd.read_csv('NLkNNwc.csv')

# %%
#LF.shape

# %%
#LF.head()

# %%
#Lfinalm = LF.loc[(LF['Cluster Labels'] == 0)]
#Lfinalm = LF

# %%
#Lfinalm.shape

# %%
#!conda install -c conda-forge geocoder --yes
#print("Installation Done!")
#import geocoder # import geocoder
#print("Geo Coder imported!")

# %% [markdown]
# def get_geocoder(Neighborhood_from_Lfinalm):
#     # initialize your variable to None
#     lat_lng_coords = None
#     # loop until you get the coordinates
#     while(lat_lng_coords is None):
#         g = geocoder.arcgis('{}, London, United Kingdom'.format(Neighborhood_from_Lfinalm.strip()))
#         lat_lng_coords = g.latlng
#         latitude = lat_lng_coords[0]
#         longitude = lat_lng_coords[1]
#     return latitude,longitude

# %%
#Lfinalm['Latitude'], Lfinalm['Longitude'] = zip(*Lfinalm['Neighborhood'].apply(get_geocoder))
#Lfinalm.head()

# %%
Lfinalm = pd.read_csv('NLkNNwsog.csv')

# %%
Lfinalm = Lfinalm[Lfinalm['Cluster Labels'] == 1]

# %%
Lfinalm.head()
# Out:
#     Neighborhood  American Restaurant  Bar  Bus Stop  Cafe  \
# 2        Aldgate                    0    0         0    10
# 3        Aldwych                    0    0         0     0
# 12   Arnos Grove                    0    0         1     0
# 33     Bayswater                    0    0         0    10
# 36  Bedford Park                    0    2         0    30
#
#     Chinese Restaurant  Clothing Store  Cocktail Bar  Coffee Shop  \
# 2                    0               0             6           90
# 3                    0               2             3           60
# 12                   0               0             0            0
# 33                   5               0             1           30
# 36                   1               2             5           70
#
#     Deli / Bodega  Fast Food Restaurant  Grocery Store  Gym / Fitness Center  \
# 2               0                     1              0                     3
# ...

# %%
from folium.plugins import MarkerCluster
from folium import plugins
from folium.plugins import HeatMap

# Map obj
map_clusters = folium.Map()

# %%
data = Lfinalm[['Latitude', 'Longitude']].values


legend_html =   '''
                <div style="position: fixed; 
                            top: 50px; right: 50px; height: 30px; background: white;
                            border:2px solid red; z-index:9999; font-size:15px;
                            ">&nbsp; Cluster 1 Neighborhoods in New York and London <br>
                              
                </div>
                ''' 
MarkerCluster(data).add_to(map_clusters).get_root().html.add_child(folium.Element(legend_html))  

map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
